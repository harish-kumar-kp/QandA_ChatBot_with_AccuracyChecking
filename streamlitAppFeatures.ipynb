# %%
context="""NASA scientists say new data provided by twin spacecraft analyzing the sun will help them more accurately predict how so-called solar tsunamis wreak havoc on our planet.NASA says new data on so-called solar tsunamis will help predict how they will affect our planetThe tsunamis -- powerful explosions known as coronal mass ejections, or CMEs -- produce solar cosmic rays that can interfere with technology, causing power blackouts and disrupting air traffic communications and cell phone networks.NASA says images captured by its twin Solar Terrestrial Relations Observatory, or STEREO, spacecraft have enabled scientists to map the tsunamis in 3D to examine their structure, velocity, mass and direction."""

# %%
findword="tsunamis in 3D"

# %%
print(context.index(findword) )
# Out:
# 633

# %%
pip install streamlit-player
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from streamlit_player import st_player

st_player('https://www.youtube.com/watch?v=Tdd5-LWBrFg')

# %%
st_player('https://www.youtube.com/watch?v=Tdd5-LWBrFg')

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\final NLP QA Project\\Codes'

# %%
import json

books = {"book_details":[
        {
        "title": "The Great Gatsby",
        "author": "F. Scott Fitzgerald",
        "publication_year": 1925,
        "genre": "Fiction"
        },
        {
        "title": "To Kill a Mockingbird",
        "author": "Harper Lee",
        "publication_year": 1960,
        "genre": "Fiction"
        },
        {
        "title": "1984",
        "author": "George Orwell",
        "publication_year": 1949,
        "genre": "Fiction"
        }
]
}

# %%
# Convert and write JSON object to file
with open("sample.json", "w") as outfile: 
    json.dump(books, outfile)

# %%
# Opening JSON file
f = open('sample.json')

# returns JSON object as a dictionary
data = json.load(f)

# Iterating through the json list
for i in data['book_details']:
    print(i['title'] ,i['genre'] ,i['author'] ,i['publication_year'])



# Closing file
f.close()
# Out:
# The Great Gatsby Fiction F. Scott Fitzgerald 1925
# To Kill a Mockingbird Fiction Harper Lee 1960
# 1984 Fiction George Orwell 1949

# %%
subString ="man"
Fruit_list = ['Banana', 'Apple', 'Mango']
print("String present in the index:\n")
# iterate through the list of elements
for i in Fruit_list:
# check for type is str
    if subString in i.lower():
# display index
        print(Fruit_list.index(i))
# Out:
# String present in the index:
#
# 2

# %%
import json

data = {"topicDetails":[
        {
        "topicTitle": ["Topic 1","Topic One","Voice-Activated Technology"],
        "contextText": """Voice-activated technology has become more sophisticated, with devices now able to understand and process natural human speech more accurately. This technology is widely used in smart speakers, home automation, and customer service bots. It enhances accessibility, convenience, and interaction with technology through hands-free commands and is increasingly integrated into vehicles and public spaces.""",
        "videoLink": "https://www.youtube.com/watch?v=FQRcNiFx0lg",
        "imageLink": "https://www.nojitter.com/sites/default/files/voice-recognition-graphic.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Speech_recognition",
        "keywords":"Topic One,Topic 1,Voice Activated "
        },
        {
        "topicTitle": ["Topic 2","Topic Two","Telemedicine"],
        "contextText": """Telemedicine allows patients to consult with doctors via digital platforms, reducing the need for physical visits. Providing continued medical care during situations like the COVID-19 pandemic has become vital. Telemedicine is expanding to include more services and is becoming a regular mode of healthcare delivery.""",
        "videoLink": "https://www.youtube.com/watch?v=IWWbi8yDTRs",
        "imageLink": "https://esoftskills.com/healthcare/wp-content/uploads/2023/12/revolutionizing_healthcare_through_telemedicine.jpg",
        "referenceLink": "https://www.news-medical.net/health/What-is-Telemedicine.aspx",
        "keywords":"Topic Two,Topic 2,Telemedicine,medicine"
        },
        {
        "topicTitle": ["Topic 3","Topic Three","3D Printing"],
        "contextText": """3D printing or additive manufacturing is the construction of a three-dimensional object from a CAD model or a digital 3D model. It can be done in a variety of processes in which material is deposited, joined or solidified under computer control, with the material being added together, typically layer by layer.""",
        "videoLink": "https://www.youtube.com/watch?v=Vx0Z6LplaMU",
        "imageLink": "https://d2jx2rerrg6sh3.cloudfront.net/image-handler/ts/20240105075307/ri/750/src/images/Article_Images/ImageForArticle_23929_17044591877731537.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/3D_printing",
        "keywords":"Topic Three,Topic 3,3D Printing"
        },
        {
        "topicTitle": ["Topic 4","Topic Four","Quantum Computers"],
        "contextText": """Quantum computers leverage the properties of quantum mechanics to process information exponentially faster than classical computers for specific tasks. This year,we're seeing quantum computing being applied in areas such as cryptography, where it can potentially crack currently considered secure codes and in drugdiscovery, speeding up the process by accurately simulating molecular structures. The technology is still nascent but poised to revolutionize industries by solving complex problems intractable for traditional computers.""",
        "videoLink": "https://www.youtube.com/watch?v=uPOA4-Hm7og",
        "imageLink": "https://ijcsmc.com/wp-content/uploads/2023/04/Quantum_Computing_Image.png",
        "referenceLink": "https://en.wikipedia.org/wiki/Quantum_computing",
        "keywords":"Topic Four,Topic 4,Quantum Computers"
        },
        {
        "topicTitle": ["Topic 5","Topic Five","Autonomous Vehicles"],
        "contextText": """Autonomous vehicles use AI, sensors, and machine learning to navigate and operate without human intervention. While fully autonomous cars are still under development,there's significant progress in integrating levels of autonomy into public transportation and freight logistics, which could reduce accidents, improve traffic management, and decrease emissions.""",
        "videoLink": "https://www.youtube.com/watch?v=gEy91PGGLR0",
        "imageLink": "https://miro.medium.com/v2/resize:fit:1100/format:webp/1*FTJMhrszSbvunwHtnErVhg.jpeg",
        "referenceLink": "https://en.wikipedia.org/wiki/Self-driving_car",
        "keywords":"Topic Five,Topic 5,Autonomous Vehicles"
        },
        {
        "topicTitle": ["Topic 6","Topic Six","Extended reality (XR)"],
        "contextText":"""Extended reality (XR) encompasses virtual reality (VR), augmented reality (AR), and mixed reality (MR), providing immersive training experiences. Industries like healthcare,aviation,and manufacturing use XR for risk-free, hands-on training simulations replicating real-life scenarios. This technology improves learning outcomes, enhances engagement, and reduces training costs.""" ,
        "videoLink": "https://www.youtube.com/watch?v=m_o99lJb-_4",
        "imageLink": "https://i.ytimg.com/vi/E0QLVj9FJ0A/hq720.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Extended_reality",
        "keywords":"Topic Six,Topic 6,Extended reality (XR),extended,reality"
        },
        {
        "topicTitle": ["Topic 7","Topic Seven","Commercial Space Travel"],
        "contextText": """Commercial space travel is making significant strides with companies like SpaceX and Blue Origin. These developments aim to make space travel accessible for more than just astronauts. Current offerings range from short suborbital flights providing a few minutes of weightlessness to plans for orbital flights. Space tourism opens new avenues for adventure and pushes the envelope in aerospace technology and research.""",
        "videoLink": "https://www.youtube.com/watch?v=eH-xm9G9QBk",
        "imageLink": "https://i.ytimg.com/vi/SyUItEiZbbk/hq720.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Space_tourism",
        "keywords":"Topic Seven,Topic 7,Commercial Space Travel"
        },
        {
        "topicTitle": ["Topic 8","Topic Eight","Robotics Technology"],
        "contextText": """Robotics technology has evolved to create machines that can perform complex tasks autonomously or with minimal human oversight. These robots are employed in various sectors, including manufacturing, where they perform precision tasks, healthcare as surgical assistants, and homes as personal aids. AI and machine learning advances are making robots even more capable and adaptable.""",
        "videoLink": "https://www.youtube.com/watch?v=VM2AUU9jmNg",
        "imageLink": "https://intorobotics.com/wp-content/uploads/2024/01/image-3.jpeg",
        "referenceLink": "https://robotnik.eu/what-is-advanced-robotics-advanced-industrial-robotics/",
        "keywords":"Topic Eight,Topic 8,Robotics,Robotic"
        },
        {
        "topicTitle": ["Topic 9","Topic Nine","Wearable Health Monitor"],
        "contextText": """Advanced wearable devices now continuously monitor various health metrics like heart rate, blood pressure, and even blood sugar levels. These devices connect to smartphones and use AI to analyze data, providing users with insights into their health and early warnings about potential health issues. This trend is driving a shift towards preventive healthcare and personalized health insights.""",
        "videoLink": "https://www.youtube.com/watch?v=iwtjAY81ZzU",
        "imageLink": "https://upload.wikimedia.org/wikipedia/commons/b/b4/Schematic_diagram_of_a_remote_health_monitoring_system_based_on_wearable_sensors.webp",
        "referenceLink": "https://en.wikipedia.org/wiki/Wearable_technology#Applications_to_COVID-19",
        "keywords":"Topic Nine,Topic 9,Wearable Health Monitor"
        },
        {
        "topicTitle": ["Topic 10","Topic Ten","MetaHuman"],
        "contextText": """MetaHuman is a complete framework that gives any creator the power to create and use fully rigged, photorealistic digital humans in a variety of projects powered by Unreal Engine 5 .Which is used forGames and Movies in Recent Years which is applied with machine learning capabilities""",
        "videoLink": "https://www.youtube.com/watch?v=S3F1vZYpH8c",
        "imageLink": "https://i.ytimg.com/vi/ND9uLGk2Kgo/hq720.jpg",
        "referenceLink": "https://www.unrealengine.com/en-US/metahuman",
        "keywords":"Topic Ten,Topic 10,MetaHuman"
        }
]
}



# Convert and write JSON object to file
with open("tech_trend.json", "w") as outfile: 
    json.dump(data, outfile)

# %%
# Opening JSON file
f = open('tech_trend.json')

# returns JSON object as a dictionary
data = json.load(f)

# Iterating through the json list
for i in data['topicDetails']:
    print(i['topicTitle'][0]+" : "+i['topicTitle'][2] )
    print(i['contextText'])
    print(i['videoLink'] , i['imageLink'] ,  i['referenceLink'] )
    print(i['keywords'])
    print("-----------------")
    



# Closing file
f.close()
# Out:
# Topic 1 : Voice-Activated Technology
# Voice-activated technology has become more sophisticated, with devices now able to understand and process natural human speech more accurately.
#             This technology is widely used in smart speakers, home automation, and customer service bots. It enhances accessibility, convenience, and interaction with technology
#             through hands-free commands and is increasingly integrated into vehicles and public spaces.
# https://www.youtube.com/watch?v=FQRcNiFx0lg https://www.nojitter.com/sites/default/files/voice-recognition-graphic.jpg https://en.wikipedia.org/wiki/Speech_recognition
# Topic One , Voice Activated Technology
# -----------------
# Topic 2 : Telemedicine
# Telemedicine allows patients to consult with doctors via digital platforms, reducing the need for physical visits. Providing continued medical care during
# ...

# %%
# Opening JSON file
f = open('tech_trend.json')

# returns JSON object as a dictionary
data = json.load(f)
# creating list
topicTitleLst=[]
contextLst=[]
vidLnkLst=[]
imgLnkLst=[]
refLnkLst=[]
kewwordLst=[]
# Iterating through the json list
for i in data['topicDetails']:
    topicTitleLst.append(i['topicTitle'])
    contextLst.append(i['contextText'])
    vidLnkLst.append(i['videoLink'])
    imgLnkLst.append(i['imageLink'])
    refLnkLst.append(i['referenceLink'])
    kewwordLst.append(i['keywords'])

print(topicTitleLst )
print(contextLst)
print(vidLnkLst)
print(imgLnkLst)
print(refLnkLst)
print(kewwordLst)
print("-----------------")
    



# Closing file
f.close()
# Out:
# [['Topic 1', 'Topic One', 'Voice-Activated Technology'], ['Topic 2', 'Topic Two', 'Telemedicine'], ['Topic 3', 'Topic Three', '3D Printing'], ['Topic 4', 'Topic Four', 'Quantum Computers'], ['Topic 5', 'Topic Five', 'Autonomous Vehicles'], ['Topic 6', 'Topic Six', 'Extended reality (XR)'], ['Topic 7', 'Topic Seven', 'Commercial Space Travel'], ['Topic 8', 'Topic Eight', 'Robotics Technology'], ['Topic 9', 'Topic Nine', 'Wearable Health Monitor'], ['Topic 10', 'Topic Ten', 'MetaHuman']]
# ...

# %%
topicTitleLst[0][0] +" : "+topicTitleLst[0][2]
# Out:
# 'Topic 1 : Voice-Activated Technology'

# %%
topicChoose ="autonomous vehicle"
print("String present in the index:\n")
# iterate through the list of elements
for i in kewwordLst:
# check for type is str
    if topicChoose in i.lower():
# display index
        #print(kewwordLst.index(i))
        idx = kewwordLst.index(i)
print(topicTitleLst[idx][2])    
print(contextLst[idx])   
print(vidLnkLst[idx])    
print(imgLnkLst[idx]) 
print(refLnkLst[idx])
# Out:
# String present in the index:
#
# Autonomous Vehicles
# Autonomous vehicles use AI, sensors, and machine learning to navigate and operate without human intervention. While fully autonomous cars are still under development,
#             there's significant progress in integrating levels of autonomy into public transportation and freight logistics, which could reduce accidents, improve traffic management, and decrease emissions.
# https://www.youtube.com/watch?v=gEy91PGGLR0
# https://miro.medium.com/v2/resize:fit:1100/format:webp/1*FTJMhrszSbvunwHtnErVhg.jpeg
# https://en.wikipedia.org/wiki/Self-driving_car

# %%
topicChoose ="3d printing"
print("String present in the index:\n")
# iterate through the list of elements
for i in kewwordLst:
    subString = i.lower().split()
    for j in subString:
        if j in topicChoose:
            idx = kewwordLst.index(i)

print(topicTitleLst[idx][2])    
print(contextLst[idx])   
print(vidLnkLst[idx])    
print(imgLnkLst[idx]) 
print(refLnkLst[idx])
# Out:
# String present in the index:
#
# 3D Printing
# 3D printing or additive manufacturing is the construction of a three-dimensional object from a CAD model or a digital 3D model. It can be done in a
#             variety of processes in which material is deposited, joined or solidified under computer control, with the material being added together, typically layer by layer.
# https://www.youtube.com/watch?v=Vx0Z6LplaMU
# https://d2jx2rerrg6sh3.cloudfront.net/image-handler/ts/20240105075307/ri/750/src/images/Article_Images/ImageForArticle_23929_17044591877731537.jpg
# https://en.wikipedia.org/wiki/3D_printing

# %%
import json

data = {"topicDetails":[
        {
        "topicTitle": ["Topic 1","Topic One","Pasta Carbonara"],
        "contextText": """Description: A creamy, savory pasta made with eggs, cheese, pancetta, and pepper. Ingredients: Spaghetti, eggs, Parmesan cheese, pancetta, black pepper, salt .
        Since the name is derived from carbonaro, some people believe the dish was first made as a hearty meal for Italian charcoal workers. In parts of the United States, this etymology 
        gave rise to the term coal miner's spaghetti.John F. Mariani writes that some people believe it was created as a tribute to the Carbonari (lit.'charcoal burners') secret society 
        prominent in the early, repressed stages of Italian unification (Risorgimento) in the early 19th century.It seems more probable that it is an "urban dish" from Rome. 
        Spice Level: Mild . Country of Origin: Italy.""",
        "videoLink": "https://www.youtube.com/watch?v=4F1JcvnsBRc",
        "imageLink": "https://colavitarecipes.com/wp-content/uploads/2020/04/carbonara.jpeg",
        "referenceLink": "https://en.wikipedia.org/wiki/Carbonara",
        "keywords":"Topic One,Topic 1,Pasta,Carbonara,Pasta Carbonara"
        },
        {
        "topicTitle": ["Topic 2","Topic Two","Pizza Margherita"],
        "contextText": """Description: Traditional pizza topped with fresh tomatoes, mozzarella cheese, and basil, representing the colors of the Italian flag.A popular contemporary legend holds that 
        the archetypal pizza Margherita was invented in June 1889, when the Royal Palace of Capodimonte commissioned the Neapolitan pizzaiolo Raffaele Esposito to create a pizza in honor of the visiting 
        Queen Margherita. Of the three different pizzas he created, the queen strongly preferred a pizza swathed in the colors of the Italian tomato, green (basil), and white (mozzarella). Supposedly, 
        this type of pizza was then named after the queen. Ingredients: Pizza dough, fresh tomatoes, mozzarella cheese, basil, olive oil, salt. Spice Level: Mild . Country of Origin: Italy.""",
        "videoLink": "https://www.youtube.com/watch?v=ft97dd4amUI",
        "imageLink": "https://www.yumcurry.com/wp-content/uploads/2020/06/pizza-margherita-recipe.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Pizza_Margherita",
        "keywords":"Topic Two,Topic 2,Pizza,Margherita,Pizza Margherita "
        },
        {
        "topicTitle": ["Topic 3","Topic Three","Macaroni and Cheese"],
        "contextText": """Description: A creamy and cheesy pasta dish, loved worldwide.Cheese and pasta casseroles were recorded in the 14th century in the Italian cookbook Liber de Coquina, which featured a 
        dish of Parmesan cheese and pasta. A cheese and pasta casserole known as makerouns, was recorded in the 14th-century medieval English cookbook the Forme of Cury.Ingredients: Macaroni pasta, cheddar cheese, milk, butter, flour, salt, black pepper.
        Spice Level: Mild .Country of Origin: United States (popularized)""",
        "videoLink": "https://www.youtube.com/watch?v=YxVZuuxxXxk",
        "imageLink": "https://hips.hearstapps.com/hmg-prod/images/mac-and-cheese-index-64d25bdf03b98.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Macaroni_and_cheese",
        "keywords":"Topic Three,Topic 3,Macaroni,Cheese,Macaroni and Cheese"
        },
        {
        "topicTitle": ["Topic 4","Topic Four","Lasagna Bolognese"],
        "contextText": """Description: Lasagna originated in Italy during the Middle Ages. The oldest transcribed text about lasagna appears in 1282 in the Memoriali Bolognesi ('Bolognese Memorials'), in which lasagna was mentioned in a poem transcribed by a Bolognese notary.
        it has Layers of pasta, meat sauce, and béchamel, baked to perfection.Ingredients: Lasagna noodles, ground beef, tomato sauce, béchamel sauce, mozzarella, Parmesan cheese, onion, garlic, olive oil, salt, pepper.
        Spice Level: Mild to ModerateCountry of Origin: Italy """,
        "videoLink": "https://www.youtube.com/watch?v=VkQajdYciW0",
        "imageLink": "https://i0.wp.com/smittenkitchen.com/wp-content/uploads/2012/02/lasagna-bolognese-4-scaled.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Lasagna",
        "keywords":"Topic Four,Topic 4,Lasagna Bolognese,Lasagna,Bolognese,lasana,Bolones"
        },
        {
        "topicTitle": ["Topic 5","Topic Five","Pad Thai"],
        "contextText": """Description: A flavorful Thai noodle dish, stir-fried with tofu, peanuts, and vegetables, usually with a balance of sweet, salty, and sour flavors .Pad Thai was originally called "Kuai Tiao Pad Thai" but this was later shortened to simply Pad Thai.
        Ingredients: Rice noodles, shrimp or tofu, peanuts, bean sprouts, eggs, tamarind paste, fish sauce, lime, chili flakes.Spice Level: Moderate . Country of Origin: Thailand.""",
        "videoLink": "https://www.youtube.com/watch?v=qcTP4o_2SlE",
        "imageLink": "https://www.foodandwine.com/thmb/fVg4StV4O2ZRK3QHCGo4qpAZUzw=/750x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/Shrimp-Pad-Thai-FT-RECIPE0324-3132ca704bc0457e836127dbda403368.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Pad_thai",
        "keywords":"Topic Five ,Topic 5,Pad Thai,Pad,thai,part time,pod,thoi"
        },
        {
        "topicTitle": ["Topic 6","Topic Six","Spaghetti Aglio e Olio"],
        "contextText":"""Description: Simple yet delicious pasta made with garlic, olive oil, and red pepper flakes.This dish is typical of the Italian city of Naples, in the Campania region , This dish was once also known as vermicelli alla Borbonica.
        Ingredients: Spaghetti, garlic, olive oil, red pepper flakes, parsley, Parmesan cheese, salt. Spice Level: Moderate .Country of Origin: Italy.""" ,
        "videoLink": "https://www.youtube.com/watch?v=a0EyzJsf1eo",
        "imageLink": "https://i0.wp.com/walkingthroughlavenderfields.com/wp-content/uploads/2022/09/aglio-e-olio-e-peperoncino-01.jpeg",
        "referenceLink": "https://en.wikipedia.org/wiki/Spaghetti_aglio_e_olio",
        "keywords":"Topic Six,Topic 6,Spaghetti Aglio e Olio,Spaghetti,Aglio,Olio "
        },
        {
        "topicTitle": ["Topic 7","Topic Seven","Ramen"],
        "contextText": """Description: A comforting Japanese noodle soup with broth, noodles, meat, and vegetables.Ramen is a Japanese noodle dish. It consists of Chinese-style wheat noodles served in a broth.
        Ingredients: Ramen noodles, chicken or pork broth, soy sauce, mirin, green onions, seaweed, boiled egg, garlic, chili paste. Spice Level: Mild to Moderate (varies) .Country of Origin: Japan""",
        "videoLink": "https://www.youtube.com/watch?v=r3_tcQiyGG8&t=12s",
        "imageLink": "https://recipes.net/wp-content/uploads/2022/09/rsz_miso-ramen-1024x683.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Ramen",
        "keywords":"Topic Seven,Topic 7,Ramen,raman"
        },
        {
        "topicTitle": ["Topic 8","Topic Eight","Tacos al Pastor"],
        "contextText": """Description: Mexican street tacos with marinated pork, pineapple, onion, and cilantro, served on corn tortillas. Al pastor (from Spanish, "herdsman style"), tacos al pastor, or tacos de trompo is a
        preparation of spit-grilled slices of pork originating in the Central Mexican region of Puebla and Mexico City.Ingredients: Corn tortillas, marinated pork, pineapple, onion, cilantro, lime, chili powder.
        Spice Level: Moderate .Country of Origin: Mexico.""",
        "videoLink": "https://www.youtube.com/watch?v=FsPbh36YBs8",
        "imageLink": "https://blog.amigofoods.com/wp-content/uploads/2021/02/tacos-al-pastor.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Al_pastor",
        "keywords":"Topic Eight,Topic 8,Tacos al Pastor,Tacos,al,Pastor"
        },
        {
        "topicTitle": ["Topic 9","Topic Nine"," Butter Chicken (Murgh Makhani) "],
        "contextText": """Description: A creamy and rich chicken curry with a mild heat and tomato-based sauce.Butter chicken, traditionally known as murgh makhani is an Indian dish originating in Delhi.
        Ingredients: Chicken, tomatoes, cream, butter, ginger, garlic, garam masala, cumin, chili powder. Spice Level: Mild to Moderate .Country of Origin: India.""",
        "videoLink": "https://www.youtube.com/watch?v=a03U45jFxOI",
        "imageLink": "https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEjfWHtzoa2a8dtPEKQYnP1B-d4ks4P7Tn_45EFHlhAHWCDPFEpaY0nvuT_nkK52UGt9QjhXYQBVLsLuLBuBjNUvHBR2rP6uNrLbYsQxXzHWQ-QytIljOB_HQNU2q_hPBK-LJcuyKT5gKeQ/s1600/IMG_20190929_213308.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Butter_chicken",
        "keywords":"Topic Nine,Topic 9,Butter Chicken,Murgh Makhani"
        },
        {
        "topicTitle": ["Topic 10","Topic Ten","Pho"],
        "contextText": """Description: A traditional Vietnamese noodle soup with fragrant broth, beef, rice noodles, and fresh herbs.Phở originated in the early 20th century in Northern Vietnam, and after the Vietnam War, refugees popularized it throughout the world.
        Ingredients: Beef or chicken broth, rice noodles, thinly sliced beef, basil, cilantro, lime, fish sauce, chili paste. Spice Level: Mild to Moderate (varies) .Country of Origin: Vietnam""",
        "videoLink": "https://www.youtube.com/watch?v=5bIjDYEs6Qc",
        "imageLink": "https://staticcookist.akamaized.net/wp-content/uploads/sites/22/2023/10/pho.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Pho",
        "keywords":"Topic Ten,Topic 10,Pho,ho"
        }
]
}



# Convert and write JSON object to file
with open("food_recipies.json", "w") as outfile: 
    json.dump(data, outfile)

# %% [markdown]
# medical dataset

# %%
import json

data = {"topicDetails":[
        {
        "topicTitle": ["Topic 1","Topic One","Circulatory System"],
        "contextText": """Organs: Heart, blood vessels (arteries, veins, capillaries), blood .Funcion: Transports oxygen, nutrients, hormones, and waste products throughout the body.Detail: The circulatory system is responsible for transporting blood, nutrients, oxygen, carbon dioxide, and hormones throughout the body. It consists of the heart, blood, and a network of blood vessels (arteries, veins, and capillaries). The heart, a muscular organ, pumps blood through these vessels in a closed-loop system, ensuring that oxygenated blood reaches the body’s tissues and organs while removing waste products like carbon dioxide. Blood vessels are classified into arteries (which carry blood away from the heart), veins (which bring blood back to the heart), and capillaries (tiny vessels where the exchange of oxygen, nutrients, and waste occurs). This system plays a vital role in maintaining body temperature, pH balance, and overall homeostasis. The circulatory system also supports the immune system by transporting white blood cells to areas of infection or injury.""",
        "videoLink": "https://www.youtube.com/watch?v=f9ONXd_-anM",
        "imageLink": "https://www.thoughtco.com/thmb/KHjPoXpHSOEayCpFLk0BKLC6Wvs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/GettyImages-97537745-59efa47d6f53ba0011c0070b.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Circulatory_system",
        "keywords":"Topic One,Topic 1,Circulatory "
        },
        {
        "topicTitle": ["Topic 2","Topic Two","Respiratory System"],
        "contextText": """Organs: Lungs, trachea, bronchi, diaphragm .Function:Provides oxygen to the blood and removes carbon dioxide from the body. Detail: The respiratory system supplies oxygen to the blood and removes carbon dioxide, a waste product of metabolism, from the body. It includes the nasal passages, pharynx, larynx, trachea, bronchi, and lungs. The process begins with inhalation, where air enters through the nose or mouth, traveling down the trachea and into the bronchi, which branch into smaller bronchioles within the lungs. These end in alveoli, small air sacs where gas exchange occurs. Oxygen from inhaled air diffuses into the bloodstream, while carbon dioxide diffuses out to be exhaled. The diaphragm, a muscle under the lungs, contracts during inhalation and relaxes during exhalation, facilitating airflow. This system works closely with the circulatory system to ensure that all cells receive the oxygen they need for energy production.""",
        "videoLink": "https://www.youtube.com/watch?v=67Jbbu7UZAA",
        "imageLink": "https://www.visiblebody.com/hs-fs/hub/189659/file-2545156127-jpg/Learn_Articles/Respiratory_System/Set_1_Five_Functions_of_Respiratory_Sys/1C-Respiratory-System.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Respiratory_system",
        "keywords":"Topic Two,Topic 2,Respiratory"
        },
        {
        "topicTitle": ["Topic 3","Topic Three","Digestive System"],
        "contextText": """Organs: Mouth, esophagus, stomach, intestines, liver, pancreas, gallbladder .Function: Breaks down food into nutrients for energy, growth, and cell repair; eliminates waste. Detail: The digestive system breaks down food into nutrients that the body can absorb and use for energy, growth, and cell repair. It includes organs such as the mouth, esophagus, stomach, intestines, liver, pancreas, and gallbladder. Digestion starts in the mouth, where enzymes in saliva begin breaking down carbohydrates. The food then moves down the esophagus to the stomach, where acids and enzymes further digest it. The partially digested food passes into the small intestine, where most nutrient absorption occurs, aided by enzymes from the pancreas and bile from the liver. The large intestine absorbs water and forms waste, which is excreted through the rectum. The digestive system also plays a role in immune defense, particularly through the gut microbiome, which helps protect against pathogens.""",
        "videoLink": "https://www.youtube.com/watch?v=_T_vmcLyTzI",
        "imageLink": "https://online-learning-college.com/wp-content/uploads/2022/05/digestive-system-2048x1317.jpeg",
        "referenceLink": "https://en.wikipedia.org/wiki/Human_digestive_system",
        "keywords":"Topic Three,Topic 3,Digestive"
        },
        {
        "topicTitle": ["Topic 4","Topic Four","Nervous System"],
        "contextText": """Organs: Brain, spinal cord, nerves, sensory organs .Function: Controls body activities by sending signals to and from different body parts; processes sensory information. Detail: The nervous system is the body’s control center, responsible for sending, receiving, and interpreting signals from all parts of the body. It includes the brain, spinal cord, and peripheral nerves. The central nervous system (CNS), composed of the brain and spinal cord, processes information and coordinates responses. The peripheral nervous system (PNS) connects the CNS to limbs and organs, allowing for communication between the brain and the rest of the body. Sensory neurons collect information from the environment, which is processed by the brain, while motor neurons control muscle actions. The autonomic nervous system, a part of the PNS, regulates involuntary activities like heartbeat and digestion. This system enables thinking, perception, voluntary movement, and coordination, impacting nearly every other system.""",
        "videoLink": "https://www.youtube.com/watch?v=VAEmxt78bBI",
        "imageLink": "https://bhoperehab.com/wp-content/uploads/2024/02/drugs-nervous-system-scaled.jpeg",
        "referenceLink": "https://en.wikipedia.org/wiki/Nervous_system",
        "keywords":"Topic Four,Topic 4,Nervous"
        },
        {
        "topicTitle": ["Topic 5","Topic Five","Muscular System"],
        "contextText": """Organs: Skeletal muscles, smooth muscles, cardiac muscles .Function: Enables movement, maintains posture, and produces heat. Detail: The muscular system enables movement, maintains posture, and produces body heat. It consists of three types of muscles: skeletal, smooth, and cardiac. Skeletal muscles, attached to bones, control voluntary movements like walking and lifting. Smooth muscles, found in organs like the intestines and blood vessels, control involuntary movements like digestion and blood flow. Cardiac muscle, found only in the heart, contracts to pump blood throughout the body. Muscles work by contracting and relaxing, often in pairs, and require signals from the nervous system to initiate action. This system is essential for physical movement, but it also plays roles in organ function and circulation.""",
        "videoLink": "https://www.youtube.com/watch?v=rMcg9YzNSEs",
        "imageLink": "https://image.slidesharecdn.com/muscularsystem-220930072848-e9f2fcba/75/Muscular-System-ppt-1-2048.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Muscular_system",
        "keywords":"Topic Five,Topic 5,Muscular"
        },
        {
        "topicTitle": ["Topic 6","Topic Six","Skeletal System"],
        "contextText":"""Organs: Bones, joints, cartilage, ligaments .Function: Supports and protects organs, enables movement, produces blood cells, and stores minerals. Detail: The skeletal system provides the body’s structural framework, protects vital organs, and works with the muscular system to facilitate movement. It includes bones, joints, cartilage, and ligaments. Bones serve several functions: they store minerals (e.g., calcium and phosphorus), produce blood cells in the bone marrow, and offer attachment points for muscles. The axial skeleton (skull, vertebral column, and rib cage) supports and protects the central nervous system and organs. The appendicular skeleton (limbs and pelvis) allows for mobility. Cartilage cushions joints, and ligaments connect bones, stabilizing and supporting movement.""" ,
        "videoLink": "https://www.youtube.com/watch?v=38MsEkhdECM",
        "imageLink": "https://cdn.britannica.com/51/54751-050-E65F3C33/Front-views-human-skeleton.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Human_skeleton",
        "keywords":"Topic Six,Topic 6,Skeletal"
        },
        {
        "topicTitle": ["Topic 7","Topic Seven","Endocrine System"],
        "contextText": """Organs: Glands such as the pituitary, thyroid, adrenal glands, pancreas .Function: Produces hormones that regulate metabolism, growth, reproduction, and other functions. Detail: The endocrine system regulates bodily functions through hormones released by glands, such as the pituitary, thyroid, adrenal glands, and pancreas. Hormones are chemical messengers that travel through the bloodstream to target organs, affecting processes like metabolism, growth, development, mood, and reproduction. For example, insulin from the pancreas regulates blood sugar levels, while adrenaline from the adrenal glands prepares the body for stress. The pituitary gland, often called the “master gland,” controls other glands, playing a central role in growth, sexual development, and metabolism. This system’s balance is crucial for homeostasis and overall health.""",
        "videoLink": "https://www.youtube.com/watch?v=ySkk7U_4PeY",
        "imageLink": "https://cdn.britannica.com/12/93312-004-6B1E3651/glands-female-human-endocrine-systems.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Endocrine_system",
        "keywords":"Topic Seven,Topic 7,Endocrine"
        },
        {
        "topicTitle": ["Topic 8","Topic Eight","Lymphatic (Immune) System"],
        "contextText": """Organs: Lymph nodes, lymphatic vessels, spleen, thymus, white blood cells .Function: Protects the body against infection and disease; returns fluid to the bloodstream. Detail: The lymphatic system is part of the immune system, defending the body against infections and disease. It consists of lymph nodes, lymph vessels, the spleen, thymus, and tonsils. Lymph, a fluid containing white blood cells, circulates through lymph vessels and filters through lymph nodes, trapping pathogens. The spleen helps fight infection and recycles old red blood cells, while the thymus is involved in T-cell maturation (a type of white blood cell). This system maintains fluid balance by returning excess tissue fluid to the bloodstream and helps absorb fats from the digestive system.""",
        "videoLink": "https://www.youtube.com/watch?v=o0-1OknbO3M",
        "imageLink": "https://cdn.slidesharecdn.com/ss_thumbnails/bsc-lymphaticsystem-240406170735-d22aaf44-thumbnail.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Lymphatic_system",
        "keywords":"Topic Eight,Topic 8,Lymphatic,Immune"
        },
        {
        "topicTitle": ["Topic 9","Topic Nine","Urinary System"],
        "contextText": """Organs: Kidneys, ureters, bladder, urethra .Function: Removes waste products from the blood, regulates water balance, and maintains electrolyte levels. Detail: The urinary system removes waste products from the body and maintains fluid and electrolyte balance. It includes the kidneys, ureters, bladder, and urethra. The kidneys filter blood to remove waste and excess substances, forming urine. This urine flows through the ureters to the bladder, where it is stored until excretion through the urethra. This system also regulates blood pressure and pH balance by adjusting the amount of water and electrolytes in the blood. It plays a critical role in homeostasis and maintaining the body's internal environment.""",
        "videoLink": "https://www.youtube.com/watch?v=CkGqp5tr-Qk",
        "imageLink": "https://i.ytimg.com/vi/zYRMJR9K4jY/hq720.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Urinary_system",
        "keywords":"Topic Nine,Topic 9,Urinary"
        },
        {
        "topicTitle": ["Topic 10","Topic Ten","Integumentary System"],
        "contextText": """Organs: Skin, hair, nails, glands .Function: Protects the body, regulates temperature, and provides sensory information. Detail: The integumentary system includes the skin, hair, nails, and glands. The skin, the body’s largest organ, serves as a protective barrier against external threats like pathogens, physical injury, and UV radiation. It also regulates temperature through sweating and blood flow adjustments. The skin contains sensory receptors that allow for the sensation of touch, pain, and temperature. Hair and nails protect and support the skin, while glands in the skin produce sweat for temperature regulation and sebum to keep the skin moisturized. This system is vital for protection, temperature regulation, and sensory perception.""",
        "videoLink": "https://www.youtube.com/watch?v=whO2ndoMnsQ",
        "imageLink": "https://mblexguide.com/wp-content/uploads/2019/10/Integumentary-system-3-e1571317762734.jpg",
        "referenceLink": "https://en.wikipedia.org/wiki/Integumentary_system",
        "keywords":"Topic Ten,Topic 10,Integumentary"
        }
]
}



# Convert and write JSON object to file
with open("medical_subject.json", "w") as outfile: 
    json.dump(data, outfile)
